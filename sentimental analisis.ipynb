# %% [markdown]
# # sentimental analysis

# %% [markdown]
# Importing libraries

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

import numpy as np
import re
import matplotlib.pyplot as plt
from keras import api, layers, optimizers, preprocessing
from keras.src.legacy.preprocessing.text import Tokenizer
from keras.api.preprocessing.sequence import pad_sequences

# %% [markdown]
# Paths to text files and reading

# %%
path_train_data_positive = 'train_positive/train_positive.txt'
path_train_data_negative = 'train_negative/train_negative.txt'

# %%
with open(path_train_data_positive, 'r', encoding='utf-8') as file:
    text_positive = file.readlines()
    text_positive[0] = text_positive[0].replace('\ufeff', '')

# %%
with open(path_train_data_negative, 'r', encoding='utf-8') as file:
    text_negative = file.readlines()
    text_negative[0] = text_negative[0].replace('\ufeff', '')

# %%
text = text_positive + text_negative
count_positive = len(text_positive)
count_negative = len(text_negative)
total_line = count_positive + count_negative
print(total_line, count_negative, count_positive)

# %%
maxWordCount = 1000
test = text[0]
tokenizer = Tokenizer(maxWordCount, char_level=False, lower=True, split=' ') # Create a tokenizer
tokenizer.fit_on_texts(text) # train the tokenizer on our text
dict_of_word = tokenizer.index_word  # We create a dictionary in which each word corresponds to a certain number
print(dict_of_word)
max_text_len = 10
data = tokenizer.texts_to_sequences(text) # We form a sequence in which words are replaced by corresponding numbers
data_pad = pad_sequences(data, maxlen=max_text_len)# We normalize each sequence. The length should be equal to 10. We cut off everything unnecessary, add zeros to short sequences on the left.
# Out:
# {1: 'не', 2: 'и', 3: 'в', 4: 'вы', 5: 'на', 6: 'я', 7: 'а', 8: 'только', 9: 'что', 10: 'все', 11: 'это', 12: 'если', 13: 'жизнь', 14: 'просто', 15: 'с', 16: 'чем', 17: 'никогда', 18: 'чтобы', 19: 'к', 20: 'у', 21: '—', 22: 'больше', 23: 'себя', 24: 'то', 25: 'всегда', 26: 'вас', 27: 'меня', 28: 'за', 29: 'вам', 30: 'когда', 31: 'от', 32: 'мне', 33: 'быть', 34: 'жизни', 35: 'есть', 36: 'но', 37: 'сделать', 38: 'без', 39: 'позитивным', 40: 'никому', 41: 'как', 42: 'ты', 43: 'тем', 44: 'для', 45: 'день', 46: 'позитивное', 47: 'своих', 48: 'мы', 49: 'много', 50: 'тебя', 51: 'никто', 52: 'такой', 53: '–', 54: 'деньги', 55: 'денег', 56: 'позитивно', 57: 'свою', 58: 'которые', 59: 'значит', 60: 'так', 61: 'них', 62: 'мечты', 63: 'нужно', 64: 'того', 65: 'ничего', 66: 'лучше', 67: 'надо', 68: 'верьте', 69: 'понедельник', 70: 'живи', 71: 'позволяйте', 72: 'хорошее', 73: 'можете', 74: 'ваши', 75: 'других', 76: 'делай', 77: 'тебе', 78: 'можешь', 79: 'успеха', 80: 'ваша', 81: 'стоит', 82: 'себе', 83: 'своей', 84: 'их', 85: 'позитив', 86: 'свои', 87: 'о', 88: 'энергию', 89: 'более', 90: 'делать', 91: 'по', 92: 'или', 93: 'нет', 94: 'кто', 95: 'во', 96: 'успеху', 97: 'пусть', 98: 'опасно', 99: 'равно', 100: 'ни', 101: 'же', 102: 'сама', 103: 'болезней', 104: 'подняться', 105: 'жизнью', 106: 'времена', 107: 'величайшим', 108: 'вашей', 109: 'продолжайте', 110: 'двигаться', 111: 'конце', 112: 'сильных', 113: 'людей', 114: 'свет', 115: 'может', 116: 'до', 117: 'настроены', 118: 'иметь', 119: 'хорошую', 120: 'строите', 121: 'эту', 122: 'позитивного', 123: 'отношения', 124: 'чудеса', 125: 'способности', 126: 'достичь', 127: 'оставайся', 128: 'доверяй', 129: 'твой', 130: 'вещи', 131: 'приносят', 132: 'радость', 133: 'верь', 134: 'опыт', 135: 'отношение', 136: 'собираетесь', 137: 'выбор', 138: 'позитивный', 139: 'всю', 140: 'свое', 141: 'время', 142: 'обиды', 143: 'думаете', 144: 'потому', 145: 'каждый', 146: 'позитивные', 147: 'позитивной', 148: 'можем', 149: 'позитивную', 150: 'станет', 151: 'контролируете', 152: 'будьте', 153: 'возможности', 154: 'таланты', 155: 'были', 156: 'из', 157: 'два', 158: 'должен', 159: 'превращай', 160: 'которую', 161: 'стать', 162: 'делает', 163: 'человека', 164: 'нужны', 165: 'либо', 166: 'всем', 167: 'настроем', 168: 'почему', 169: 'позитивность', 170: 'самое', 171: 'главное', 172: 'один', 173: 'сейчас', 174: 'вокруг', 175: 'бы', 176: 'кому', 177: 'нужен', 178: 'внешностью', 179: 'могу', 180: 'точно', 181: 'поэтому', 182: 'даже', 183: 'такая', 184: 'любит', 185: 'плохая', 186: 'мой', 187: 'этого', 188: 'тут', 189: 'этих', 190: 'тогда', 191: 'болею', 192: 'бывает', 193: 'хоть', 194: 'бывают', 195: 'заработать', 196: 'платить', 197: 'богатство', 198: 'зависти', 199: 'думайте', 200: 'способность', 201: 'достигать', 202: 'отличных', 203: 'результатов', 204: 'лучший', 205: 'ответ', 206: 'проблемы', 207: 'возникли', 208: 'смогли', 209: 'постели', 210: 'супер', 211: 'герой', 212: 'твои', 213: 'утренние', 214: 'мысли', 215: 'задают', 216: 'тон', 217: 'всей', 218: 'твоей', 219: 'неделе', 220: 'увидеть', 221: 'становишься', 222: 'сильнее', 223: 'живешь', 224: 'счастливой', 225: 'полноценной', 226: 'утренним', 227: 'проблемам', 228: 'помешать', 229: 'успешным', 230: 'тяжелые', 231: 'часто', 232: 'приводят', 233: 'моментам', 234: 'трудности', 235: 'концов', 236: 'создают', 237: 'независимо', 238: 'через', 239: 'проходите', 240: 'туннеля', 241: 'показаться', 242: 'добраться', 243: 'него', 244: 'сложно', 245: 'сможете', 246: 'говорите', 247: 'хочу', 248: 'реальность', 249: 'принятие', 250: 'ко', 251: 'всему', 252: 'происходящему', 253: 'творить', 254: 'настроение', 255: 'добавляет', 256: 'годы', 257: 'весну', 258: 'вашему', 259: 'шагу', 260: 'искорку', 261: 'ваших', 262: 'глазах', 263: 'природные', 264: 'важны', 265: 'многого', 266: 'целеустремленность', 267: 'окружите', 268: 'позитивными', 269: 'людьми', 270: 'верят', 271: 'поддерживают', 272: 'идеи', 273: 'прости', 274: 'инвестируй', 275: 'своим', 276: 'инстинктам', 277: 'позво ...

# %% [markdown]
# Forming a training sample

# %%
X = data_pad
Y = np.array([[1, 0]] * count_positive + [[0 , 1]] * count_negative)
print(X.shape, Y.shape)

# %%
indeces = np.random.choice(X.shape[0], size=X.shape[0], replace=False) # Mixing the sample
X = X[indeces]
Y = Y[indeces]

# %% [markdown]
# Creating a neural network model

# %%
model = api.Sequential() 
model.add(layers.Embedding(input_dim=maxWordCount, output_dim=128, input_length=max_text_len)) # We will feed the input with a tensor of dimension (172, 10).Number of output neurons 128
model.add(layers.LSTM(128, return_sequences=True)) # Add a LSTM layer. The number of neurons in the fully connected layers of LSTM block is 128.At the output we form a sequence.
model.add(layers.LSTM(64)) # Return the last value of the sequence
model.add(api.layers.Dense(units=2, activation='softmax'))#Linear layer for predicting the result.

model.summary()

# %%
model.compile(optimizer=api.optimizers.Adam(0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x=X, y=Y, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.5893 - loss: 0.6920
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6830 - loss: 0.6884
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6791 - loss: 0.6848
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7373 - loss: 0.6791
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7393 - loss: 0.6737
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7753 - loss: 0.6684
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7850 - loss: 0.6587
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8337 - loss: 0.6373
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8375 - loss: 0.6182
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8208 - loss: 0.5922
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8351 - loss: 0.5694
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8369 - loss: 0.5634
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8216 - loss: 0.5140
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8619 - loss: 0.4809
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8747 - loss: 0.4559
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8305 - loss: 0.5084
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8410 - loss: 0.4491
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8673 - loss: 0.4020
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8692 - loss: 0.4027
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8872 - loss: 0.3740
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8823 - loss: 0.3378
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8774 - loss: 0.3327
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8985 - loss: 0.3213
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9014 - loss: 0.2860
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9145 - loss: 0.2503
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9184 - loss: 0.2321
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9376 - loss: 0.2122
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9313 - loss: 0.1988
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9508 - loss: 0.1611
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9792 - loss: 0.1209
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9679 - loss: 0.1307
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9823 - loss: 0.0995
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9663 - loss: 0.1028
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9864 - loss: 0.0847
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9782 - loss: 0.0789
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9804 - loss: 0.0673
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9778 - loss: 0.0682
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9873 - loss: 0.0479
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9689 - loss: 0.0653
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9948 - loss: 0.0453
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9873 - loss: 0.0345
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9912 - loss: 0.0297
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0338
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0366
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9881 - loss: 0.0335
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9881 - loss: 0.0360
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9881 - loss: 0.0369
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9974 - loss: 0.0218
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9974 - loss: 0.0177
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0195
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9963 - loss: 0.0217
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9881 - loss: 0.0232
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0183
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9963 - loss: 0.0148
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0209
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9983 - loss: 0.0142
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0159
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0185
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0153
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0145
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0106
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0101
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9926 - loss: 0.0122
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0080
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0110
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0102
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0061
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9983 - loss: 0.0062
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0055
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0042
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0035

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['loss'])
plt.legend(('accuracy','loss'))

# %%
def get_sentimental(text):
    text_seq = tokenizer.texts_to_sequences([text.lower()])
    print(f"Words used:: {seq_to_text(text_seq)}")
    inp = pad_sequences(text_seq, maxlen=max_text_len)
    pred = np.argmax(model.predict(inp))
    return 'negation' if pred == 1 else 'positive'

def seq_to_text(list_of_index):
    words = [dict_of_word[elem] for elem in list_of_index[0]]
    return words

# %%
print(f"Результат : {get_sentimental('Это самый лучший день в моей жизни')}")
print(f"Результат : {get_sentimental('Это самый худший день в моей жизни')}")
# Out:
# Анализируемые слова: ['это', 'лучший', 'день', 'в', 'жизни']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Результат : positive
# Анализируемые слова: ['это', 'день', 'в', 'жизни']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Результат : negation
